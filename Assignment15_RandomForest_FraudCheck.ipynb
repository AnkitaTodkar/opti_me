# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

from sklearn import preprocessing
from sklearn.model_selection import train_test_split

from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df_fraud= pd.read_csv("D:\Ankita\Assignments\\Fraud_checkRF.csv")
df_fraud
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# 595                7   YES
# 596                2   YES
# 597                0   YES
# 598               17    NO
# 599               16    NO
#
# [600 rows x 6 columns]

# %%
df_fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Undergrad        600 non-null    object
#  1   Marital.Status   600 non-null    object
#  2   Taxable.Income   600 non-null    int64
#  3   City.Population  600 non-null    int64
#  4   Work.Experience  600 non-null    int64
#  5   Urban            600 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 28.2+ KB

# %%
df_fraud.rename(columns = {'Marital.Status':'Marital_status', 'Taxable.Income':'Taxable_income', 
                                'City.Population':'City_population', 'Work.Experience':'Work_experience'}, inplace = True)

# %%
# Converting Sales feature into categorical type

taxable_inc = pd.cut(df_fraud.Taxable_income, bins=[0, 30000, 100000], labels=['Risky', 'Good'])

df_fraud.drop(['Taxable_income'], axis=1, inplace=True)
df_fraud.insert(0, 'Taxable_income', taxable_inc)

df_fraud
# Out:
#     Taxable_income Undergrad Marital_status  City_population  Work_experience  \
# 0             Good        NO         Single            50047               10
# 1             Good       YES       Divorced           134075               18
# 2             Good        NO        Married           160205               30
# 3             Good       YES         Single           193264               15
# 4             Good        NO        Married            27533               28
# ..             ...       ...            ...              ...              ...
# 595           Good       YES       Divorced            39492                7
# 596           Good       YES       Divorced            55369                2
# 597           Good        NO       Divorced           154058                0
# 598           Good       YES        Married           180083               17
# 599           Good        NO       Divorced           158137               16
#
#     Urban
# 0     YES
# 1     YES
# 2     YES
# 3     YES
# 4      NO
# ..    ...
# 595   YES
# 596   YES
# 597   YES
# 598    NO
# 599    NO
#
# [600 rows x 6 columns]

# %%
label_en = preprocessing.LabelEncoder()
df_fraud['Undergrad'] = label_en.fit_transform(df_fraud['Undergrad'])

df_fraud.Undergrad
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 595    1
# 596    1
# 597    0
# 598    1
# 599    0
# Name: Undergrad, Length: 600, dtype: int32

# %%
df_fraud['Marital_status'] = label_en.fit_transform(df_fraud['Marital_status'])

df_fraud.Marital_status
# Out:
# 0      2
# 1      0
# 2      1
# 3      2
# 4      1
#       ..
# 595    0
# 596    0
# 597    0
# 598    1
# 599    0
# Name: Marital_status, Length: 600, dtype: int32

# %%
df_fraud['Urban'] = label_en.fit_transform(df_fraud['Urban'])

df_fraud.Urban
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 595    1
# 596    1
# 597    1
# 598    0
# 599    0
# Name: Urban, Length: 600, dtype: int32

# %%
df_fraud
# Out:
#     Taxable_income  Undergrad  Marital_status  City_population  \
# 0             Good          0               2            50047
# 1             Good          1               0           134075
# 2             Good          0               1           160205
# 3             Good          1               2           193264
# 4             Good          0               1            27533
# ..             ...        ...             ...              ...
# 595           Good          1               0            39492
# 596           Good          1               0            55369
# 597           Good          0               0           154058
# 598           Good          1               1           180083
# 599           Good          0               0           158137
#
#      Work_experience  Urban
# 0                 10      1
# 1                 18      1
# 2                 30      1
# 3                 15      1
# 4                 28      0
# ..               ...    ...
# 595                7      1
# 596                2      1
# 597                0      1
# 598               17      0
# 599               16      0
#
# [600 rows x 6 columns]

# %%
df_fraud.isna().sum()
# Out:
# Taxable_income     0
# Undergrad          0
# Marital_status     0
# City_population    0
# Work_experience    0
# Urban              0
# dtype: int64

# %% [markdown]
# **Outlier detection using 'isolation forest'**

# %%
from sklearn.ensemble import IsolationForest

# %%
df_copy = df_fraud.copy()
data_encoded = pd.get_dummies(df_copy)

# %%
# training the isolation forest model

clf = IsolationForest(random_state=10, contamination=.01)
clf.fit(data_encoded)
# Out:
# C:\Users\Nishad Todkar\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.01, random_state=10)

# %%
# predictions

y_pred_outliers = clf.predict(data_encoded)
data_encoded
# Out:
#      Undergrad  Marital_status  City_population  Work_experience  Urban  \
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
#      Taxable_income_Risky  Taxable_income_Good
# 0                       0                    1
# 1                       0                    1
# 2                       0                    1
# 3                       0                    1
# 4                       0                    1
# ..                    ...                  ...
# 595                     0                    1
# 596                     0                    1
# 597                     0                    1
# 598                     0                    1
# 599                     0                    1
#
# [600 rows x 7 columns]

# %%
data_encoded['scores'] = clf.decision_function(data_encoded)
data_encoded['anomaly'] = clf.predict(data_encoded.iloc[:, 0:7])
data_encoded
# Out:
#      Undergrad  Marital_status  City_population  Work_experience  Urban  \
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
#      Taxable_income_Risky  Taxable_income_Good    scores  anomaly
# 0                       0                    1  0.128597        1
# 1                       0                    1  0.131005        1
# 2                       0                    1  0.084827        1
# 3                       0                    1  0.104186        1
# 4                       0                    1  0.097489        1
# ..                    ...                  ...       ...      ...
# 595                     0                    1  0.095277        1
# 596                     0                    1  0.075817        1
# 597                     0                    1  0.067130        1
# 598                     0                    1  0.141565        1
# 599                     0                    1  0.130338        1
#
# [600 rows x 9 columns]

# %%
# Print the outlier data points

data_encoded[data_encoded['anomaly']==-1]
# Out:
#      Undergrad  Marital_status  City_population  Work_experience  Urban  \
# 16           1               0            34551               29      0
# 34           1               0           183767                1      1
# 126          1               0           195022                3      1
# 168          0               0           167629               30      0
# 280          0               0            33184                1      0
# 541          1               0           191874               30      1
#
#      Taxable_income_Risky  Taxable_income_Good    scores  anomaly
# 16                      1                    0 -0.005177       -1
# 34                      1                    0 -0.016414       -1
# 126                     1                    0 -0.016731       -1
# 168                     1                    0 -0.002113       -1
# 280                     1                    0 -0.022976       -1
# 541                     1                    0 -0.006491       -1

# %%
df_fraud.drop([16, 34, 126, 168, 280, 541], inplace=True)
df_fraud
# Out:
#     Taxable_income  Undergrad  Marital_status  City_population  \
# 0             Good          0               2            50047
# 1             Good          1               0           134075
# 2             Good          0               1           160205
# 3             Good          1               2           193264
# 4             Good          0               1            27533
# ..             ...        ...             ...              ...
# 595           Good          1               0            39492
# 596           Good          1               0            55369
# 597           Good          0               0           154058
# 598           Good          1               1           180083
# 599           Good          0               0           158137
#
#      Work_experience  Urban
# 0                 10      1
# 1                 18      1
# 2                 30      1
# 3                 15      1
# 4                 28      0
# ..               ...    ...
# 595                7      1
# 596                2      1
# 597                0      1
# 598               17      0
# 599               16      0
#
# [594 rows x 6 columns]

# %% [markdown]
# **Model building -Random Forest**

# %%
# Splitting data into feature and class

X = df_fraud.iloc[:,1:]
Y = df_fraud.iloc[:,0]
Y
# Out:
# 0      Good
# 1      Good
# 2      Good
# 3      Good
# 4      Good
#        ...
# 595    Good
# 596    Good
# 597    Good
# 598    Good
# 599    Good
# Name: Taxable_income, Length: 594, dtype: category
# Categories (2, object): ['Risky' < 'Good']

# %%
X
# Out:
#      Undergrad  Marital_status  City_population  Work_experience  Urban
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
# [594 rows x 5 columns]

# %%
# Split the data into train and test dataset

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, stratify=Y)

# %%
# Model building

num_trees = 100
max_features = 2
kfold = KFold(n_splits=10, random_state=7, shuffle=True)

model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features, oob_score=True)
results = cross_val_score(model, X, Y, cv=kfold)

print(results.mean())
# Out:
# 0.7608474576271187

# %%
# for accuracy

model.fit(x_train, y_train)
pred = model.predict(x_train)

accuracy = accuracy_score(y_train, pred)

accuracy
# Out:
# 1.0

# %%
# confusion matrix

from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(y_train, pred)
confusion
# Out:
# array([[381,   0],
#        [  0,  94]], dtype=int64)

# %%
##Prediction on test data

pred_test = model.predict(x_test)
acc_test = accuracy_score(y_test, pred_test)

acc_test
# Out:
# 0.7310924369747899

# %%
#plot decision tree in random forest

fig = plt.figure(figsize=(15, 10))

fn = [ 'Undergrad', 'Marital_status', 'City.Population',
       'Work.Experience', 'Urban']
cn = ['Risky', 'Good']

plot_tree(model.estimators_[0], 
          feature_names=fn,
          class_names=cn, 
          filled=True, impurity=True, 
          rounded=True)
# Out:
# [Text(0.7020285087719298, 0.9666666666666667, 'City.Population <= 154345.0\ngini = 0.257\nsamples = 296\nvalue = [403, 72]\nclass = Risky'),
#  Text(0.46984649122807015, 0.9, 'Marital_status <= 1.5\ngini = 0.287\nsamples = 228\nvalue = [299, 63]\nclass = Risky'),
#  Text(0.2543859649122807, 0.8333333333333334, 'Marital_status <= 0.5\ngini = 0.336\nsamples = 142\nvalue = [180, 49]\nclass = Risky'),
#  Text(0.1074561403508772, 0.7666666666666667, 'Undergrad <= 0.5\ngini = 0.243\nsamples = 67\nvalue = [91, 15]\nclass = Risky'),
#  Text(0.05701754385964912, 0.7, 'Urban <= 0.5\ngini = 0.198\nsamples = 32\nvalue = [48, 6]\nclass = Risky'),
#  Text(0.02631578947368421, 0.6333333333333333, 'City.Population <= 144863.5\ngini = 0.111\nsamples = 20\nvalue = [32, 2]\nclass = Risky'),
#  Text(0.017543859649122806, 0.5666666666666667, 'City.Population <= 115451.5\ngini = 0.059\nsamples = 19\nvalue = [32, 1]\nclass = Risky'),
#  Text(0.008771929824561403, 0.5, 'gini = 0.0\nsamples = 13\nvalue = [22, 0]\nclass = Risky'),
#  Text(0.02631578947368421, 0.5, 'Work.Experience <= 16.0\ngini = 0.165\nsamples = 6\nvalue = [10, 1]\nclass = Risky'),
#  Text(0.017543859649122806, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [7, 0]\nclass = Risky'),
#  Text(0.03508771929824561, 0.43333333333333335, 'City.Population <= 118348.5\ngini = 0.375\nsamples = 3\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.02631578947368421, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.043859649122807015, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.03508771929824561, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.08771929824561403, 0.6333333333333333, 'Work.Experience <= 22.5\ngini = 0.32\nsamples = 12\nvalue = [16, 4]\nclass = Risky'),
#  Text(0.07894736842105263, 0.5666666666666667, 'City.Population <= 136424.0\ngini = 0.408\nsamples = 9\nvalue = [10, 4]\nclass = Risky'),
#  Text(0.06140350877192982, 0.5, 'City.Population <= 54407.0\ngini = 0.18\nsamples = 6\nvalue = [9, 1]\nclass = Risky'),
#  Text(0.05263157894736842, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.07017543859649122, 0.43333333333333335, 'gini = 0.0\nsamples = 5\nvalue = [9, 0]\nclass = Risky'),
#  Text(0.09649122807017543, 0.5, 'City.Population <= 147858.5\ngini = 0.375\nsamples = 3\nvalue = [1, 3]\nclass = Good'),
#  Text(0.08771929824561403, 0.43333333333333335, 'City.Population <= 144284.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.07894736842105263, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.09649122807017543, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.10526315789473684, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.09649122807017543, 0.5666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [6, 0]\nclass = Risky'),
#  Text(0.15789473684210525, 0.7, 'Urban <= 0.5\ngini = 0.286\nsamples = 35\nvalue = [43, 9]\nclass = Risky'),
#  Text(0.12280701754385964, 0.6333333333333333, 'City.Population <= 53173.0\ngini = 0.252\nsamples = 20\nvalue = [23, 4]\nclass = Risky'),
#  Text(0.11403508771929824, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.13157894736842105, 0.5666666666666667, 'Work.Experience <= 20.5\ngini = 0.204\nsamples = 19\nvalue = [23, 3]\nclass = Risky'),
#  Text(0.12280701754385964, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [17, 0]\nclass = Risky'),
#  Text(0.14035087719298245, 0.5, 'City.Population <= 101376.0\ngini = 0.444\nsamples = 7\nvalue = [6, 3]\nclass = Risky'),
#  Text(0.13157894736842105, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.14912280701754385, 0.43333333333333335, 'Work.Experience <= 28.5\ngini = 0.49\nsamples = 6\nvalue = [4, 3]\nclass = Risky'),
#  Text(0.14035087719298245, 0.36666666666666664, 'Work.Experience <= 22.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Good'),
#  Text(0.13157894736842105, 0.3, 'Work.Experience <= 21.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.12280701754385964, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.14035087719298245, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.14912280701754385, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Good'),
#  Text(0.15789473684210525, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.19298245614035087, 0.6333333333333333, 'City.Population <= 31720.0\ngini = 0.32\nsamples = 15\nvalue = [20, 5]\nclass = Risky'),
#  Text(0.18421052631578946, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.20175438596491227, 0.5666666666666667, 'City.Population <= 121471.5\ngini = 0.278\nsamples = 14\nvalue = [20, 4]\nclass = Risky'),
#  Text(0.19298245614035087, 0.5, 'Work.Experience <= 20.0\ngini = 0.227\nsamples = 13\nvalue = [20, 3]\nclass = Risky'),
#  Text(0.18421052631578946, 0.43333333333333335, 'Work.Experience <= 13.5\ngini = 0.375\nsamples = 8\nvalue = [9, 3]\nclass = Risky'),
#  Text(0.17543859649122806, 0.36666666666666664, 'gini = 0.0\nsamples = 5\nvalue = [8, 0]\nclass = Risky'),
#  Text(0.19298245614035087, 0.36666666666666664, 'City.Population <= 56586.0\ngini = 0.375\nsamples = 3\nvalue = [1, 3]\nclass = Good'),
#  Text(0.18421052631578946, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.20175438596491227, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]\nclass = Good'),
#  Text(0.20175438596491227, 0.43333333333333335, 'gini = 0.0\nsamples = 5\nvalue = [11, 0]\nclass = Risky'),
#  Text(0.21052631578947367, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.40131578947368424, 0.7666666666666667, 'Work.Experience <= 19.5\ngini = 0.4\nsamples = 75\nvalue = [89, 34]\nclass = Risky'),
#  Text(0.31359649122807015, 0.7, 'Undergrad <= 0.5\ngini = 0.451\nsamples = 43\nvalue = [46, 24]\nclass = Risky'),
#  Text(0.2412280701754386, 0.6333333333333333, 'City.Population <= 60615.0\ngini = 0.48\nsamples = 24\nvalue = [27, 18]\nclass = Risky'),
#  Text(0.2324561403508772, 0.5666666666666667, 'gini = 0.0\nsamples = 10\nvalue = [12, 0]\nclass = Risky'),
#  Text(0.25, 0.5666666666666667, 'Work.Experience <= 2.5\ngini = 0.496\nsamples = 14\nvalue = [15, 18]\nclass = Good'),
#  Text(0.22807017543859648, 0.5, 'City.Population <= 66115.0\ngini = 0.298\nsamples = 4\nvalue = [9, 2]\nclass = Risky'),
#  Text(0.21929824561403508, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.23684210526315788, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [9, 0]\nclass = Risky'),
#  Text(0.2719298245614035, 0.5, 'Urban <= 0.5\ngini = 0.397\nsamples = 10\nvalue = [6, 16]\nclass = Good'),
#  Text(0.2543859649122807, 0.43333333333333335, 'City.Population <= 93984.5\ngini = 0.245\nsamples = 2\nvalue = [1, 6]\nclass = Good'),
#  Text(0.24561403508771928, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.2631578947368421, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 6]\nclass = Good'),
#  Text(0.2894736842105263, 0.43333333333333335, 'City.Population <= 84121.0\ngini = 0.444\nsamples = 8\nvalue = [5, 10]\nclass = Good'),
#  Text(0.2807017543859649, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 7]\nclass = Good'),
#  Text(0.2982456140350877, 0.36666666666666664, 'City.Population <= 96842.5\ngini = 0.469\nsamples = 6\nvalue = [5, 3]\nclass = Risky'),
#  Text(0.2894736842105263, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.30701754385964913, 0.3, 'Work.Experience <= 7.5\ngini = 0.48\nsamples = 4\nvalue = [2, 3]\nclass = Good'),
#  Text(0.2982456140350877, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]\nclass = Good'),
#  Text(0.3157894736842105, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.38596491228070173, 0.6333333333333333, 'City.Population <= 149297.5\ngini = 0.365\nsamples = 19\nvalue = [19, 6]\nclass = Risky'),
#  Text(0.37719298245614036, 0.5666666666666667, 'Work.Experience <= 15.5\ngini = 0.33\nsamples = 18\nvalue = [19, 5]\nclass = Risky'),
#  Text(0.35964912280701755, 0.5, 'Urban <= 0.5\ngini = 0.255\nsamples = 15\nvalue = [17, 3]\nclass = Risky'),
#  Text(0.3508771929824561, 0.43333333333333335, 'Work.Experience <= 9.0\ngini = 0.469\nsamples = 6\nvalue = [5, 3]\nclass = Risky'),
#  Text(0.3333333333333333, 0.36666666666666664, 'Work.Experience <= 6.5\ngini = 0.444\nsamples = 2\nvalue = [1, 2]\nclass = Good'),
#  Text(0.32456140350877194, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.34210526315789475, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.3684210526315789, 0.36666666666666664, 'Work.Experience <= 10.5\ngini = 0.32\nsamples = 4\nvalue = [4, 1]\nclass = Risky'),
#  Text(0.35964912280701755, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.37719298245614036, 0.3, 'City.Population <= 84480.5\ngini = 0.375\nsamples = 3\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.3684210526315789, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.38596491228070173, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.3684210526315789, 0.43333333333333335, 'gini = 0.0\nsamples = 9\nvalue = [12, 0]\nclass = Risky'),
#  Text(0.39473684210526316, 0.5, 'Urban <= 0.5\ngini = 0.5\nsamples = 3\nvalue = [2, 2]\nclass = Risky'),
#  Text(0.38596491228070173, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.40350877192982454, 0.43333333333333335, 'City.Population <= 84099.0\ngini = 0.444\nsamples = 2\nvalue = [1, 2]\nclass = Good'),
#  Text(0.39473684210526316, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.41228070175438597, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.39473684210526316, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.48903508771929827, 0.7, 'Work.Experience <= 25.5\ngini = 0.306\nsamples = 32\nvalue = [43, 10]\nclass = Risky'),
#  Text(0.43859649122807015, 0.6333333333333333, 'Work.Experience <= 20.5\ngini = 0.165\nsamples = 13\nvalue = [20, 2]\nclass = Risky'),
#  Text(0.4298245614035088, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [7, 0]\nclass = Risky'),
#  Text(0.4473684210526316, 0.5666666666666667, 'Work.Experience <= 21.5\ngini = 0.231\nsamples = 11\nvalue = [13, 2]\nclass = Risky'),
#  Text(0.4298245614035088, 0.5, 'City.Population <= 41423.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.42105263157894735, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.43859649122807015, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.4649122807017544, 0.5, 'City.Population <= 46624.5\ngini = 0.153\nsamples = 8\nvalue = [11, 1]\nclass = Risky'),
#  Text(0.45614035087719296, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.47368421052631576, 0.43333333333333335, 'gini = 0.0\nsamples = 7\nvalue = [11, 0]\nclass = Risky'),
#  Text(0.5394736842105263, 0.6333333333333333, 'Undergrad <= 0.5\ngini = 0.383\nsamples = 19\nvalue = [23, 8]\nclass = Risky'),
#  Text(0.5087719298245614, 0.5666666666666667, 'City.Population <= 102061.5\ngini = 0.245\nsamples = 12\nvalue = [18, 3]\nclass = Risky'),
#  Text(0.5, 0.5, 'City.Population <= 44828.0\ngini = 0.18\nsamples = 11\nvalue = [18, 2]\nclass = Risky'),
#  Text(0.49122807017543857, 0.43333333333333335, 'gini = 0.0\nsamples = 4\nvalue = [9, 0]\nclass = Risky'),
#  Text(0.5087719298245614, 0.43333333333333335, 'Work.Experience <= 27.5\ngini = 0.298\nsamples = 7\nvalue = [9, 2]\nclass = Risky'),
#  Text(0.5, 0.36666666666666664, 'Urban <= 0.5\ngini = 0.48\nsamples = 3\nvalue = [3, 2]\nclass = Risky'),
#  Text(0.49122807017543857, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.5087719298245614, 0.3, 'City.Population <= 83214.0\ngini = 0.375\nsamples = 2\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.5, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.5175438596491229, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.5175438596491229, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [6, 0]\nclass = Risky'),
#  Text(0.5175438596491229, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.5701754385964912, 0.5666666666666667, 'City.Population <= 128226.0\ngini = 0.5\nsamples = 7\nvalue = [5, 5]\nclass = Risky'),
#  Text(0.5526315789473685, 0.5, 'City.Population <= 86462.5\ngini = 0.444\nsamples = 4\nvalue = [4, 2]\nclass = Risky'),
#  Text(0.543859649122807, 0.43333333333333335, 'Urban <= 0.5\ngini = 0.444\nsamples = 2\nvalue = [1, 2]\nclass = Good'),
#  Text(0.5350877192982456, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.5526315789473685, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.5614035087719298, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.5877192982456141, 0.5, 'Work.Experience <= 27.0\ngini = 0.375\nsamples = 3\nvalue = [1, 3]\nclass = Good'),
#  Text(0.5789473684210527, 0.43333333333333335, 'City.Population <= 144724.0\ngini = 0.444\nsamples = 2\nvalue = [1, 2]\nclass = Good'),
#  Text(0.5701754385964912, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.5877192982456141, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.5964912280701754, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.6853070175438597, 0.8333333333333334, 'Work.Experience <= 5.5\ngini = 0.188\nsamples = 86\nvalue = [119, 14]\nclass = Risky'),
#  Text(0.6765350877192983, 0.7666666666666667, 'gini = 0.0\nsamples = 14\nvalue = [23, 0]\nclass = Risky'),
#  Text(0.694078947368421, 0.7666666666666667, 'City.Population <= 153880.5\ngini = 0.222\nsamples = 72\nvalue = [96, 14]\nclass = Risky'),
#  Text(0.6853070175438597, 0.7, 'City.Population <= 37547.5\ngini = 0.21\nsamples = 71\nvalue = [96, 13]\nclass = Risky'),
#  Text(0.6228070175438597, 0.6333333333333333, 'City.Population <= 36518.5\ngini = 0.426\nsamples = 7\nvalue = [9, 4]\nclass = Risky'),
#  Text(0.6140350877192983, 0.5666666666666667, 'Urban <= 0.5\ngini = 0.18\nsamples = 6\nvalue = [9, 1]\nclass = Risky'),
#  Text(0.6052631578947368, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [7, 0]\nclass = Risky'),
#  Text(0.6228070175438597, 0.5, 'Work.Experience <= 17.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.6140350877192983, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.631578947368421, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.631578947368421, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 3]\nclass = Good'),
#  Text(0.7478070175438597, 0.6333333333333333, 'Undergrad <= 0.5\ngini = 0.17\nsamples = 64\nvalue = [87, 9]\nclass = Risky'),
#  Text(0.6798245614035088, 0.5666666666666667, 'Work.Experience <= 6.5\ngini = 0.169\nsamples = 27\nvalue = [39, 4]\nclass = Risky'),
#  Text(0.6578947368421053, 0.5, 'Urban <= 0.5\ngini = 0.444\nsamples = 2\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.6491228070175439, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.6666666666666666, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.7017543859649122, 0.5, 'City.Population <= 126362.0\ngini = 0.139\nsamples = 25\nvalue = [37, 3]\nclass = Risky'),
#  Text(0.6842105263157895, 0.43333333333333335, 'City.Population <= 66205.0\ngini = 0.061\nsamples = 20\nvalue = [31, 1]\nclass = Risky'),
#  Text(0.6754385964912281, 0.36666666666666664, 'Work.Experience <= 20.0\ngini = 0.124\nsamples = 10\nvalue = [14, 1]\nclass = Risky'),
#  Text(0.6666666666666666, 0.3, 'Urban <= 0.5\ngini = 0.198\nsamples = 6\nvalue = [8, 1]\nclass = Risky'),
#  Text(0.6578947368421053, 0.23333333333333334, 'City.Population <= 63521.0\ngini = 0.32\nsamples = 4\nvalue = [4, 1]\nclass = Risky'),
#  Text(0.6491228070175439, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.6666666666666666, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.6754385964912281, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]\nclass = Risky'),
#  Text(0.6842105263157895, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [6, 0]\nclass = Risky'),
#  Text(0.6929824561403509, 0.36666666666666664, 'gini = 0.0\nsamples = 10\nvalue = [17, 0]\nclass = Risky'),
#  Text(0.7192982456140351, 0.43333333333333335, 'Work.Experience <= 24.0\ngini = 0.375\nsamples = 5\nvalue = [6, 2]\nclass = Risky'),
#  Text(0.7105263157894737, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.7280701754385965, 0.36666666666666664, 'Work.Experience <= 28.5\ngini = 0.245\nsamples = 4\nvalue = [6, 1]\nclass = Risky'),
#  Text(0.7192982456140351, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.7368421052631579, 0.3, 'City.Population <= 133049.5\ngini = 0.375\nsamples = 3\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.7280701754385965, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.7456140350877193, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.8157894736842105, 0.5666666666666667, 'Work.Experience <= 8.0\ngini = 0.171\nsamples = 37\nvalue = [48, 5]\nclass = Risky'),
#  Text(0.7894736842105263, 0.5, 'Urban <= 0.5\ngini = 0.375\nsamples = 6\nvalue = [6, 2]\nclass = Risky'),
#  Text(0.7719298245614035, 0.43333333333333335, 'City.Population <= 127754.0\ngini = 0.375\nsamples = 3\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.7631578947368421, 0.36666666666666664, 'City.Population <= 108267.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.7543859649122807, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.7719298245614035, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.7807017543859649, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]\nclass = Risky'),
#  Text(0.8070175438596491, 0.43333333333333335, 'City.Population <= 64758.5\ngini = 0.375\nsamples = 3\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.7982456140350878, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.8157894736842105, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.8421052631578947, 0.5, 'Work.Experience <= 17.0\ngini = 0.124\nsamples = 31\nvalue = [42, 3]\nclass = Risky'),
#  Text(0.8333333333333334, 0.43333333333333335, 'gini = 0.0\nsamples = 11\nvalue = [20, 0]\nclass = Risky'),
#  Text(0.8508771929824561, 0.43333333333333335, 'City.Population <= 128310.0\ngini = 0.211\nsamples = 20\nvalue = [22, 3]\nclass = Risky'),
#  Text(0.8333333333333334, 0.36666666666666664, 'Work.Experience <= 28.5\ngini = 0.159\nsamples = 18\nvalue = [21, 2]\nclass = Risky'),
#  Text(0.8245614035087719, 0.3, 'Work.Experience <= 27.0\ngini = 0.208\nsamples = 13\nvalue = [15, 2]\nclass = Risky'),
#  Text(0.7982456140350878, 0.23333333333333334, 'City.Population <= 63275.0\ngini = 0.133\nsamples = 10\nvalue = [13, 1]\nclass = Risky'),
#  Text(0.7894736842105263, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [7, 0]\nclass = Risky'),
#  Text(0.8070175438596491, 0.16666666666666666, 'Work.Experience <= 21.5\ngini = 0.245\nsamples = 5\nvalue = [6, 1]\nclass = Risky'),
#  Text(0.7982456140350878, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.8157894736842105, 0.1, 'City.Population <= 69691.0\ngini = 0.375\nsamples = 3\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.8070175438596491, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.8245614035087719, 0.03333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.8508771929824561, 0.23333333333333334, 'Urban <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.8421052631578947, 0.16666666666666666, 'City.Population <= 98157.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.8333333333333334, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.8508771929824561, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.8596491228070176, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.8421052631578947, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [6, 0]\nclass = Risky'),
#  Text(0.868421052631579, 0.36666666666666664, 'Urban <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Risky'),
#  Text(0.8596491228070176, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.8771929824561403, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.7028508771929824, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.9342105263157895, 0.9, 'Work.Experience <= 22.5\ngini = 0.147\nsamples = 68\nvalue = [104, 9]\nclass = Risky'),
#  Text(0.9122807017543859, 0.8333333333333334, 'City.Population <= 192353.5\ngini = 0.193\nsamples = 45\nvalue = [66, 8]\nclass = Risky'),
#  Text(0.8947368421052632, 0.7666666666666667, 'Marital_status <= 0.5\ngini = 0.095\nsamples = 37\nvalue = [57, 3]\nclass = Risky'),
#  Text(0.8859649122807017, 0.7, 'Work.Experience <= 11.5\ngini = 0.255\nsamples = 12\nvalue = [17, 3]\nclass = Risky'),
#  Text(0.8596491228070176, 0.6333333333333333, 'Work.Experience <= 10.5\ngini = 0.444\nsamples = 5\nvalue = [4, 2]\nclass = Risky'),
#  Text(0.8508771929824561, 0.5666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.868421052631579, 0.5666666666666667, 'City.Population <= 159508.0\ngini = 0.444\nsamples = 2\nvalue = [1, 2]\nclass = Good'),
#  Text(0.8596491228070176, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.8771929824561403, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = Good'),
#  Text(0.9122807017543859, 0.6333333333333333, 'City.Population <= 179298.5\ngini = 0.133\nsamples = 7\nvalue = [13, 1]\nclass = Risky'),
#  Text(0.9035087719298246, 0.5666666666666667, 'Work.Experience <= 17.5\ngini = 0.375\nsamples = 3\nvalue = [3, 1]\nclass = Risky'),
#  Text(0.8947368421052632, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]\nclass = Risky'),
#  Text(0.9122807017543859, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.9210526315789473, 0.5666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [10, 0]\nclass = Risky'),
#  Text(0.9035087719298246, 0.7, 'gini = 0.0\nsamples = 25\nvalue = [40, 0]\nclass = Risky'),
#  Text(0.9298245614035088, 0.7666666666666667, 'Marital_status <= 0.5\ngini = 0.459\nsamples = 8\nvalue = [9, 5]\nclass = Risky'),
#  Text(0.9210526315789473, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [7, 0]\nclass = Risky'),
#  Text(0.9385964912280702, 0.7, 'City.Population <= 192857.5\ngini = 0.408\nsamples = 6\nvalue = [2, 5]\nclass = Good'),
#  Text(0.9298245614035088, 0.6333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]\nclass = Good'),
#  Text(0.9473684210526315, 0.6333333333333333, 'Urban <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Risky'),
#  Text(0.9385964912280702, 0.5666666666666667, 'Work.Experience <= 13.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Good'),
#  Text(0.9298245614035088, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Good'),
#  Text(0.9473684210526315, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.956140350877193, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Risky'),
#  Text(0.956140350877193, 0.8333333333333334, 'Urban <= 0.5\ngini = 0.05\nsamples = 23\nvalue = [38, 1]\nclass = Risky'),
#  Text(0.9473684210526315, 0.7666666666666667, 'gini = 0.0\nsamples = 12\nvalue = [23, 0]\nclass = Risky'),
#  Text(0.9649122807017544, 0.7666666666666667, 'Undergrad <= 0.5\ngini = 0.117\nsamples = 11\nvalue = [15, 1]\nclass = Risky'),
#  Text(0.956140350877193, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [5, 0]\nclass = Risky'),
#  Text(0.9736842105263158, 0.7, 'Work.Experience <= 26.0\ngini = 0.165\nsamples = 7\nvalue = [10, 1]\nclass = Risky'),
#  Text(0.9649122807017544, 0.6333333333333333, 'gini = 0.0\nsamples = 4\nvalue = [8, 0]\nclass = Risky'),
#  Text(0.9824561403508771, 0.6333333333333333, 'Work.Experience <= 28.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Risky'),
#  Text(0.9736842105263158, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Good'),
#  Text(0.9912280701754386, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Risky')]

# %%
# save as png file
fig.savefig('random_forest_fraudCheck.png')
